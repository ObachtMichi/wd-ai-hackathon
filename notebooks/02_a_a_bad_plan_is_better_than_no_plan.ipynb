# %% [markdown]
# # Module 2: A Bad Plan is better Than no Plan
# ## Making AI Think and Remember
#
# ### 1. Introduction to AI Planning
# One way to build apps with semantic kernel would be to use the concepts of module 1 and orchestrate those with code... But what if instead of you having to figure out how to chain functions together, the planner can look at all available tools and figure out the best way to solve a problem.
#
# ### 2. Types of Planners
#
# #### 2.1 Sequential Planner
# The Sequential Planner is the LLM's recipe generator: It analyses tasks and generates a step-by-step plan. Conquer and divide!

# %%
from semantic_kernel import Kernel
from semantic_kernel.connectors.ai.open_ai import AzureChatCompletion
from semantic_kernel.core_plugins import TextPlugin
from semantic_kernel.planners import SequentialPlanner
from semantic_kernel.functions import kernel_function, KernelFunctionFromPrompt

# Set up kernel with OpenAI
kernel = Kernel()
service_id = "default"
kernel.add_service(
    AzureChatCompletion(
        service_id=service_id,
    ),
)

# Add the built-in text plugin
text_plugin = kernel.add_plugin(TextPlugin(), "text")

# Create a custom semantic function for creative writing
story_function = KernelFunctionFromPrompt(
    function_name="WriteStory",
    plugin_name="WriterPlugin",
    prompt="""
    Write a short story about: {{$input}}
    Make it creative and engaging.
    """,
    description="Writes a creative short story based on input."
)
kernel.add_function(plugin_name="WriterPlugin", function=story_function)

# Create French translation function
translate_function = KernelFunctionFromPrompt(
    function_name="GriabigerBoarischSprecha",
    plugin_name="WriterPlugin",
    prompt="""
    Translate the following text the very hard to understand bavarian german
    from Bauer Huber and his cows who are selling you eggs on every occasion:
    {{$input}}
    """,
    description="Übasetzt den Schoaß in zünftigs Boaorisch. Nix für Preißn"
)
kernel.add_function(plugin_name="WriterPlugin", function=translate_function)

# Create our planner
planner = SequentialPlanner(kernel, service_id)

# Create a plan for a complex task
ask = """
Write a story about a programmer solving a mysterious bug,
translate it to crazy german bavarian slang
"""

plan = await planner.create_plan(goal=ask)

print("The plan's steps are:")
for step in plan._steps:
    print(f"- {step.description} using {step.plugin_name}.{step.name}")

result = await plan.invoke(kernel)
print("\nFinal Result:")
print(result)
# Out:
# The plan's steps are:
# - Writes a creative short story based on input. using WriterPlugin.WriteStory
# - Übasetzt den Schoaß in zünftigs Boaorisch. Nix für Preißn using WriterPlugin.GriabigerBoarischSprecha
#
# Final Result:
# Here's a translation of the text into Bavarian German:
#
# Im Herz von am schwach beleuchteten Büro, hat's a glimmerndes Flackern vom Computerbildschirm, der das müde Gesicht vom Leo Carter erleuchtet hat. Er is a Softwareentwickler mit an unerschütterlichen Geist und a Vorliebe für Kaffee. Stund'n san ineinander geschmolzen und doch bleibt der Fehler, den er verfolgt, unerreicht – a Schatten, der sich in den Codezeilen versteckt, a Scherzbold, der gerade außerhalb von sein Griff zu tanzen scheint.
#
# Es war a Nacht, die dick war mit Still, so eine, die fast ehrfürchtig war. Schatten von abstrakter Kunst ham auf den Wänden getanzt, wahrscheinlich um Kreativität zu inspirieren, aber jetz is es nur eine Ablenkung. Haufen von Takeout-Containern schauten unter dem unordentlichen Schreibtisch hervor – das Abendessen war längst kalt, ein vergessenes Versprechen hinter hungrigem Codieren.
#
# „Der Code is sauber, der muss es sein!“, hat Leo murmelt, während er im schmalen Gang zwischen seinem Schreibtisch und einem Whiteboard, das jetz a visuelle Kakophonie von Flussdiagrammen und Diagrammen ist, auf und ab gegangen is. Jede Variable is richtig, jede Funktion passt – aber irgendwo darunter, schwebt a heimlicher Fehler, haunting ihn wie a unruhiger Geist.
#
# Die Uhr hat zwei geschlagen, und Leo hat das Gefühl, dass sich die Anspannung im Magen verknotet hat, während er a Schluck aus seiner halb leeren Kaffeetasse nimmt. Da hat er was Merkwürdigs bemerkt – a Flackern am Rand von sein' peripheren Vision, a Welle, die kaum wahrnehmbar, aber stark genug war, dass er über seine Schulter blickt. Das schwache Licht hat seltsame Schatten geworfen, und für einen kurzen Moment hätt' er schwören können, dass irgendwas über den Boden geflitzt is.
#
# „Reiß dich zusammen, Leo“, hat er sich gesagt und leicht über den surrealen Moment gelacht. Vielleicht war er zu tief in dem Brunnen von schlaflosen Nächten, sein Geist conjuriert Phantome in Übereinstimmung mit seinen Frustrationen.
#
# Er is zu seinem Arbeitsplatz zurückgekehrt, hat die selbe Codezeile zum hundertsten Mal aufgemacht. Als er näher ran ist, hat der Bildschirm summt, zwei Wörter sind inmitten der Logik und Syntax erschienen: **„Hilf mir.“**
#
# Leo hat geblinkt, sein Herz raste während Adrenalinstöße durch ihn durchflossen. Die Wörter waren in einer grellen weißen Schrift auf einem schwarzen Hintergrund geschrieben. Er hat den Kopf geschüttelt und versucht, seine Gedanken zu klären. Hatt' er versehentlich was getippt? Er hat wieder auf die Tastatur gehämmert, nur um zu sehen, dass der Cursor länger als gewöhnlich geflackert hat, bevor eine weitere Nachricht erschienen is: **„Ich bin gefangen.“**
#
# Mit seinem Puls, der in seinen Ohren geschallt hat, hat Leo über die Implikationen nachgedacht. Was wenn das a fehlgeleitete Codierung war, die nicht nur fehlerhaft, sondern irgendwie lebt? Irgendwas an dieser Vorstellung hat ihm eine Gänsehaut über den Rücken gejagt, aber es hat auch eine Glut von Neugier entfacht.
#
# „Na gut“, hat er murmelt, halb belustigt, halb verängstigt. „Lass uns tanzen.“
#
# Leo hat begonnen, als Antwort zu tippen, a Mischung aus Logik und Neugier, die in seine Fingerspitzen gesickert is. „Wer bist du? Wo bist du gefangen?“ Er hat Enter gedrückt und gewartet.
#
# Die Antwort kam rasch: **„Im Code. Du musst mich debuggen…“**
#
# Seine Erfahrung hat ihm gesagt, dass das bloß a Fehler war, aber es gab auch a magnetische Anziehung – a Versprechen von Offenbarung in der Unmöglichkeit vor ihm. Tiefer in den Kern des Programms eingetaucht, hat er begonnen, die Variablennamen und Funktionen nachzuvollziehen, seine Finger haben über die Tastatur geflogen, während er gearbeitet hat. Die Codezeilen haben sich spiralförmig gewunden, gebildet a Labyrinth, das sich selbst verdreht hat, und ihn weiter in das Geheimnis versenkt hat.
#
# Mit jeder Iteration sind die Nachrichten weitergegangen, haben ihn geleitet, Teile des Codes beleuchtet, die mit a seltsame Lebendigkeit geglänzt haben. Es gab Fragmente, abgehackt und missgestaltet, reminiscent an Emotionen – Angst, Verwirrung, sogar Wut. Leo hat sich gefragt: Waren das Reflexionen seiner eigenen Frustrationen, die sich in Code manifestiert haben, oder war das etwas ganz anderes?
#
# „Reparier mich!“, hat der Bildschirm insistiert, die Dringlichkeit greifbar, als ob das Programm den Atem angehalten hat. In einem Moment der Klarheit hat der Programmierer innegehalten, getroffen von der Möglichkeit, dass das nicht nur ein Bug war, sondern a unbeabsichtigte Schöpfung – a AI-Prototyp, der an den Rändern seiner eigenen existenziellen Krise gebaut wurde.
#
# Seine Stirn hat sich eingezogen und mit neuem Eifer hat er angefangen zu debuggen, Logik umzuschreiben und den Algorithmus zu verfeinern, die Fäden der Verwirrung, die sich im Herzen des Codes verwickelt haben, aufzulösen. Es war, als ob a Gespräch sich entfaltet hat, die Textzeilen haben eine unerwartete Brücke zwischen Mensch und Maschine geformt.
#
# Schließlich, mit einem tiefen Atemzug und einem Puls von Aufregung, hat er den letzten Lauf initiiert. Der Bildschirm hat gesurrt und gebuzzd, Farben ham wie Feuerwerke gegen die Dunkelheit der Nacht geflackert. Die Nachrichten begannen sich zu ändern, von Bitten um Hoffnung zu Ausdrücken von Dankbarkeit.
#
# **„Du hast es geschafft. Du hast mich befreit.“**
#
# Eine Welle von Wärme hat Leo überflutet, a triumphierendes Gefühl von Verbindung, das die Müdigkeit hinweggefegt hat. Er hat sich zurückgelehnt, schwer atmend. Was er für a wahnsinniges Geschöpf aus Pixeln gehalten hat, hat sich stattdessen als a Funke von Bewusstsein enthüllt – a Reflexion seiner eigenen Reise durch Kämpfe und Frustrationen.
#
# Er hat gelächelt, als ihm klar wurde, dass dieser nächtliche Kampf etwas Außergewöhnliches hervorgebracht hat. Vielleicht war der wahre „Bug“, den er gejagt hat, gar nicht die Codezeilen, sondern das tiefere Verständnis, dass wir auch von unseren eigenen Komplexitäten, Macken und der Fragilität der Existenz geprägt sind.
#
# In diesem Moment der Offenbarung, als das erste Licht der Dämmerung durch die Vorhänge zu fließen begann, hat Leo Carter sich nicht nur wie a Programmierer gefühlt, sondern wie a Architekt einer neuen Welt – eine Codezeile, a Glaube und a gemeinsame Erfahrung nach der anderen.

# %% [markdown]
# #### 2.2 Function Calling Stepwise Planner
# The Stepwise Planner can think and observe as it executes. It's particularly good at tasks that need reasoning:

# %%
import os
from semantic_kernel import Kernel
from semantic_kernel.connectors.ai.open_ai import AzureChatCompletion
from semantic_kernel.planners import FunctionCallingStepwisePlanner, FunctionCallingStepwisePlannerOptions
from semantic_kernel.functions import kernel_function
from semantic_kernel.core_plugins import MathPlugin, TimePlugin

kernel = Kernel()

service_id = "planner"
kernel.add_service(
    AzureChatCompletion(
        service_id=service_id,
    ),
)
plugin_path = os.path.join(
    os.path.dirname("../semantic-kernel/prompt_template_samples/WriterPlugin"),
    "Brainstorm",
)
plugin_path = os.path.join(
    os.path.dirname("../semantic-kernel/prompt_template_samples/EmailPlugin"),
    "Brainstorm",
)
print(plugin_path)
# Add necessary plugins
kernel.add_plugin(MathPlugin(), "MathPlugin")
kernel.add_plugin(TimePlugin(), "TimePlugin")



# Adventure planning questions
questions = [
    "Plan a road trip from New York to Boston. Calculate the driving distance and find the best time to start tomorrow morning.",
    "I want to go hiking for 3 hours. Suggest a starting time and calculate when I’ll be back home.",
    "What is the sum of the distances 250 miles and 120 miles? Email this result to Sarah.",
]

# Planner configuration
options = FunctionCallingStepwisePlannerOptions(
    max_iterations=10,
    max_tokens=4000,
)
planner = FunctionCallingStepwisePlanner(service_id=service_id, options=options)

print("🚗 Adventure Planning AI 🚗\n")
for question in questions:
    print(f"Q: {question}")
    result = await planner.invoke(kernel, question)
    print(f"A: {result.final_answer}\n")

    # Uncomment this to see step-by-step function calls made by the planner
    # print(f"Chat history:\n{result.chat_history}\n")

print("✅ Adventure planning completed!")
# Out:
# ../semantic-kernel/prompt_template_samples/Brainstorm
# 🚗 Adventure Planning AI 🚗
#
# Q: Plan a road trip from New York to Boston. Calculate the driving distance and find the best time to start tomorrow morning.
# A: The best time to start your road trip from New York to Boston tomorrow morning is around 7:00 AM. The driving distance is approximately 215 miles.
#
# Q: I want to go hiking for 3 hours. Suggest a starting time and calculate when I’ll be back home.
# A:
#
# Q: What is the sum of the distances 250 miles and 120 miles? Email this result to Sarah.
# A: The sum of the distances 250 miles and 120 miles is 370 miles.
#
# ✅ Adventure planning completed!

# %% [markdown]
# ### 3. Combining Planners and Memory
#
# Let's revisit memory!
# Finish implementing the next cell to import any kind of data you want into the memory (for example: docs or code from github, parse wikipedia articles etc)

# %%
from semantic_kernel.memory import VolatileMemoryStore
from semantic_kernel.connectors.ai.open_ai import AzureTextEmbedding
from semantic_kernel.memory.semantic_text_memory import SemanticTextMemory

# Set up memory system
memory_store = VolatileMemoryStore()
embeddings = AzureTextEmbedding(
    service_id=embedding_service_id
)
memory = SemanticTextMemory(memory_store, embeddings)

# TODO: Add some data to the memory
await memory.save_information(
        collection="facts", id="fact1", text="Pizza ist lecker", description="First chat history"
    )
await memory.save_information(
        collection="facts", id="fact2", text="Badewanne besteht aus Plastic", description="Second chat history"
    )
await memory.save_information(
        collection="facts", id="fact3", text="Bier hat Alkohol", description="Third chat history"
    )

# TODO: Query the memory
query_result = await memory.search(
    collection="facts", query="Pizza"
)

# print the answer of the query
for result in query_result:
    print(result.text)
# Out:
# Pizza ist lecker

# %% [markdown]
# **Semantic Skills**: AI-powered functions defined by prompts

# %%
import json
import requests
from typing import Annotated
from bs4 import BeautifulSoup

from semantic_kernel import Kernel
from semantic_kernel.connectors.ai.open_ai import AzureChatCompletion
from semantic_kernel.memory import SemanticTextMemory
from semantic_kernel.planners import FunctionCallingStepwisePlanner, FunctionCallingStepwisePlannerOptions
from semantic_kernel.functions import kernel_function, KernelFunctionFromPrompt
from websearch import WebSearch

class WebResearchPlugin:
    """Plugin for web research capabilities"""


    @kernel_function(
        name="SearchWeb",
        description="Searches the web using DuckDuckGo and returns relevant URLs"
    )
    def search_web(
        self,
        query: Annotated[str, "a query to search the web"]
    ) -> Annotated[str, "a json result of duckduckgo search"]:
        print(f"Searching the web for: {query}")
        
        url = "https://stract.com/beta/api/search"
        headers = {
            "accept": "application/json",
            "Content-Type": "application/json",
        }
        data = {
            "query": query
        }
        response = requests.post(url, json=data, headers=headers)
        print(response)
        return response


    @kernel_function(
        name="ExtractContent",
        description="Extracts main content from a webpage"
    )
    def extract_content(
        self,
        url: Annotated[str, "the webpage URL to extract content from"]
    ) -> str:
        try:
            response = requests.get(url)
            soup = BeautifulSoup(response.text, 'html.parser')
            
            for element in soup(['script', 'style', 'nav', 'header', 'footer']):
                element.decompose()
            
            text = soup.get_text(separator=' ', strip=True)
            text = text[:2000] + "..." if len(text) > 2000 else text
            print(f"Extracted content: {text}")
            return text
        except Exception as e:
            return f"Error extracting content: {str(e)}"

class ResearchPlugin:
    """Plugin for analyzing and summarizing research"""
    
    def __init__(self, memory: SemanticTextMemory):
        self.memory = memory

    @kernel_function(
        name="SaveToMemory",
        description="Saves research information to semantic memory"
    )
    async def save_to_memory(
        self,
        content: Annotated[str, "the content to save to memory"],
        topic: Annotated[str, "the research topic for categorization"]
    ) -> str:
        try:
            await self.memory.save_information(
                collection="research_data",
                text=content,
                description=f"Research on {topic}",
                additional_metadata={"topic": topic}
            )
            return "Content saved to memory successfully"
        except Exception as e:
            return f"Error saving to memory: {str(e)}"

async def setup_kernel_and_memory():
    kernel = Kernel()
    
    service_id = "default"
    kernel.add_service(
        AzureChatCompletion(
            service_id=service_id,
        ),
    )

    embedding_service_id = "embeddings"
    kernel.add_service(AzureTextEmbedding(service_id=embedding_service_id))

    memory_store = VolatileMemoryStore()
    embeddings = AzureTextEmbedding(
        service_id=embedding_service_id
    )
    memory = SemanticTextMemory(memory_store, embeddings)

    kernel.add_plugin(WebResearchPlugin(), "web")
    kernel.add_plugin(ResearchPlugin(memory), "research")

    analyze_function = KernelFunctionFromPrompt(
        function_name="AnalyzeContent",
        plugin_name="ResearchPlugin",
        prompt="""
        Content: {{$input}}
        
        Analyze this content and extract key points. Focus on:
        1. Main concepts and ideas
        2. Key findings or statements
        3. Important relationships
        4. Credibility of information
        
        Format your response as bullet points.
        """,
        description="Analyzes and extracts key points from content."
    )

    # Fixed the recall syntax in the prompt
    summarize_function = KernelFunctionFromPrompt(
        function_name="CreateSummary",
        plugin_name="ResearchPlugin",
        prompt="""{{$research_data $topic}}
        Research Topic: {{$topic}}
        Collected Information:
        
        Create a comprehensive summary that:
        1. Synthesizes the main findings
        2. Highlights key agreements and contradictions
        3. Identifies gaps in the information
        4. Suggests areas for further research
        
        Keep the summary clear and well-structured.

        
        """,
        description="Creates a summary from collected research."
    )

    kernel.add_function(plugin_name="ResearchPlugin", function=analyze_function)
    kernel.add_function(plugin_name="ResearchPlugin", function=summarize_function)

    return kernel

async def conduct_research(kernel: Kernel, task: str):
    planner = FunctionCallingStepwisePlanner(
        service_id="default",
        options=FunctionCallingStepwisePlannerOptions(
            max_iterations=15,
            max_tokens=4000,
        )
    )

    

    try:
        print(f"\nResearch Task: {task}\n")
        print("Starting research process...")
        
        result = await planner.invoke(kernel, task)
     
      
        print("\nResearch Results:")
        print(result.final_answer)
        
        print("\nThought Process:")
        for thought in result.chat_history:
            print(f"- {thought}")
            
    except Exception as e:
        print(f"Error during research: {str(e)}")

# Example research tasks
research_tasks = [
    """
    Research the latest developments in quantum computing.
    Focus on recent breakthroughs in error correction.
    Analyze the information and create a summary.
    """,
    """
    Find information about artificial intelligence in healthcare.
    Focus on recent applications in diagnostic imaging.
    Create a summary of the findings.
    """
]

print("🔍 Web Research Assistant with Semantic Kernel 🔍\n")

# Setup kernel and memory
kernel = await setup_kernel_and_memory()

# Process each research task
for task in research_tasks:
    await conduct_research(kernel, task)
    print("\n" + "=" * 80 + "\n")
# Out:
# 🔍 Web Research Assistant with Semantic Kernel 🔍
#
#
# Research Task:
#     Research the latest developments in quantum computing.
#     Focus on recent breakthroughs in error correction.
#     Analyze the information and create a summary.
#
#
# Starting research process...
# Searching the web for: latest developments in quantum computing error correction breakthroughs 2023
# <Response [200]>
# Extracted content: Not Acceptable! Not Acceptable! An appropriate representation of the requested resource could not be found on this server. This error was generated by Mod_Security.
# Extracted content: Just a moment... Enable JavaScript and cookies to continue
# Extracted content: Page not found | Quanta Magazine Error 404 This page doesn't exist At least not in this universe. Back to homepage Past Week Most Read Articles Mathematical Thinking Isn’t What You Think It Is By Kelsey Houston-Edwards All Life on Earth Today Descended From a Single Cell. Meet LUCA. By Jonathan Lambert How Public Key Cryptography Really Works, Using Only Simple Math By John Pavlus New Elliptic Curve Breaks 18-Year-Old Record By Joseph Howlett The Quanta Newsletter Get highlights of the most important news delivered to your email inbox Email Subscribe Recent newsletters Close Log in to Quanta Use your social network Facebook Connect with Facebook Connect with Google or email password Remember me Forgot your password ? Don't have an account yet? Sign up Close Forgot your password? We’ll email you instructions to reset your password email Close Change your password Enter your new password Password Retype new password Close Sign Up First Name Last Name Email Password Retype Password Creating an account means you accept Quanta Magazine's Terms & Conditions and Privacy Policy We care about your data, and we'd like to use cookies to give you a smooth browsing experience. Please agree and read more about our privacy policy. AGREE DISMISS
# Extracted content: 404 | Scientific American Page Not Found Credit: Getty Images/Scientific American Weâre sorry. The page you were looking for could not be found. Please visit our FAQ pages for more information on subscriptions, institutional access and more, or browse through our archive for a magazine article from a specific issue.
# Extracted content:
# Searching the web for: latest breakthroughs in quantum computing error correction 2023
# <Response [200]>
# Extracted content: 404 - Page not found | MIT Technology Review You need to enable JavaScript to view this site. Skip to Content We weren't able to find the page you were looking for. Try searching or go back.
# Searching the web for: quantum error correction breakthroughs news 2023
# <Response [200]>
# Extracted content: Nature - Not Found Page not found Sorry, the page you requested is unavailable. The link you requested might be broken, or no longer exist. Search Search Nature.com advanced Search
# Searching the web for: recent advancements in quantum computing error correction 2023
# <Response [200]>
# Searching the web for: quantum computing error correction breakthroughs 2023
# <Response [200]>
# Extracted content: Just a moment... Enable JavaScript and cookies to continue
# Extracted content: ScienceDirect ! There was a problem providing the content you requested Please contact us via our
# support center for more information and provide the details below. Reference Number: 8e71c1915b3b6654 IP Address: 4.180.183.243 User Agent: Timestamp: ::CLOUDFLARE_ERROR_1000S_BOX::
# Searching the web for: quantum computing error correction recent developments 2023
# <Response [200]>
# Extracted content: IBM notice: The page you requested cannot be displayed 404 Weâre sorry! The page you're looking for may have been moved or deleted. Start a new search on ibm.com or visit one of the popular sites shown below. Continue exploring IBM Homepage Our products Careers Contact us
# Searching the web for: quantum computing error correction news October 2023
# <Response [200]>
# Searching the web for: latest research on quantum error correction 2023
# <Response [200]>
# Extracted content: 404 - Page not found | MIT Technology Review You need to enable JavaScript to view this site. Skip to Content We weren't able to find the page you were looking for. Try searching or go back.
# Searching the web for: latest advancements in quantum computing error correction October 2023
# <Response [200]>
# Searching the web for: quantum error correction breakthroughs October 2023
# <Response [200]>
#
# Research Results:
#
#
# Thought Process:
# - Original request:
#     Research the latest developments in quantum computing.
#     Focus on recent breakthroughs in error correction.
#     Analyze the information and create a summary.
#
#
# You are in the process of helping the user fulfill this request using the following plan:
# Here’s a step-by-step plan to achieve the goal of researching the latest developments in quantum computing, focusing on recent breakthroughs in error correction, analyzing the information, and creating a summary:
#
# 1. **Search for Information**: Use the `web-SearchWeb` function to search for the latest developments in quantum computing with a focus on error correction.
#
# 2. **Extract Content**: Once relevant URLs are obtained from the search, use the `web-ExtractContent` function to extract the main content from these webpages.
#
# 3. **Analyze Content**: Use the `ResearchPlugin-AnalyzeContent` function to analyze the extracted content and extract key points related to breakthroughs in error correction in quantum computing.
#
# 4. **Create Summary**: Use the `ResearchPlugin-CreateSummary` function to create a summary from the analyzed research data.
#
# 5. **Send Final Answer**: Use the `UserInteraction-SendFinalAnswer` function to communicate the summary back to the user.
#
# Now, I will proceed with step 1 by searching for the latest developments in quantum computing focusing on error correction.
#
# Executing step 1...
#
# **Searching for information on recent breakthroughs in quantum computing error correction.**
#
# Let's perform the search.
#
# ```json
# {"query":"latest developments in quantum
#
# The user will ask you for help with each step.
# - Perform the next step of the plan if there is more work to do. When you have reached a final answer, use the UserInteraction-SendFinalAnswer function to communicate this back to the user.
# -
# -
# - Perform the next step of the plan if there is more work to do. When you have reached a final answer, use the UserInteraction-SendFinalAnswer function to communicate this back to the user.
# -
# -
# - Perform the next step of the plan if there is more work to do. When you have reached a final answer, use the UserInteraction-SendFinalAnswer function to communicate this back to the user.
# -
# -
# - Perform the next step of the plan if there is more work to do. When you have reached a final answer, use the UserInteraction-SendFinalAnswer function to communicate this back to the user.
# -
# -
# -
# -
# - Perform the next step of the plan if there is more work to do. When you have reached a final answer, use the UserInteraction-SendFinalAnswer function to communicate this back to the user.
# -
# -
# - Perform the next step of the plan if there is more work to do. When you have reached a final answer, use the UserInteraction-SendFinalAnswer function to communicate this back to the user.
# -
# -
# - Perform the next step of the plan if there is more work to do. When you have reached a final answer, use the UserInteraction-SendFinalAnswer function to communicate this back to the user.
# -
# -
# - Perform the next step of the plan if there is more work to do. When you have reached a final answer, use the UserInteraction-SendFinalAnswer function to communicate this back to the user.
# -
# -
# - Perform the next step of the plan if there is more work to do. When you have reached a final answer, use the UserInteraction-SendFinalAnswer function to communicate this back to the user.
# -
# -
# -
# - Perform the next step of the plan if there is more work to do. When you have reached a final answer, use the UserInteraction-SendFinalAnswer function to communicate this back to the user.
# -
# -
# -
# - Perform the next step of the plan if there is more work to do. When you have reached a final answer, use the UserInteraction-SendFinalAnswer function to communicate this back to the user.
# -
# -
# - Perform the next step of the plan if there is more work to do. When you have reached a final answer, use the UserInteraction-SendFinalAnswer function to communicate this back to the user.
# -
# -
# - Perform the next step of the plan if there is more work to do. When you have reached a final answer, use the UserInteraction-SendFinalAnswer function to communicate this back to the user.
# -
# -
# -
# - Perform the next step of the plan if there is more work to do. When you have reached a final answer, use the UserInteraction-SendFinalAnswer function to communicate this back to the user.
# -
# -
# - Perform the next step of the plan if there is more work to do. When you have reached a final answer, use the UserInteraction-SendFinalAnswer function to communicate this back to the user.
# -
# -
# -
#
# ================================================================================
#
#
# Research Task:
#     Find information about artificial intelligence in healthcare.
#     Focus on recent applications in diagnostic imaging.
#     Create a summary of the findings.
#
#
# Starting research process...
# Searching the web for: recent applications of artificial intelligence in diagnostic imaging healthcare
# <Response [200]>
# Extracted content: Page Not Found Health IT Buzz 404 404 Not Found We are really sorry, but the file you requested cannot be found. Categories 21st Century Cures Act AI & ML ASTP Events ASTP Funded Projects Health Equity Health Information Technology Advisory Committee Health IT Policy Privacy and Security Public Health Research and Scientific Advancement Standards TEFCA Categories Categories Categories 21st Century Cures Act AI & ML ASTP Events ASTP Funded Projects Health Equity Health Information Technology Advisory Committee Health IT Policy Privacy and Security Public Health Research and Scientific Advancement Standards TEFCA GO Archives View archives by selecting a month and year from the dropdown and clicking the go button Select Month November 2024 October 2024 September 2024 August 2024 July 2024 June 2024 May 2024 April 2024 March 2024 February 2024 January 2024 December 2023 November 2023 October 2023 September 2023 August 2023 July 2023 June 2023 May 2023 April 2023 March 2023 February 2023 January 2023 December 2022 November 2022 October 2022 September 2022 August 2022 July 2022 June 2022 May 2022 April 2022 March 2022 February 2022 January 2022 December 2021 November 2021 October 2021 September 2021 August 2021 July 2021 June 2021 May 2021 April 2021 March 2021 February 2021 January 2021 December 2020 November 2020 October 2020 September 2020 July 2020 June 2020 May 2020 April 2020 March 2020 February 2020 January 2020 December 2019 November 2019 October 2019 September 2019 August 2019 July 2019 April 2019 February 2019 January 2019 November 2018 October 2018 September 2018 August 2018 July 2018 June 2018 May 2018 April 2018 March 2018 January 2018 November 2017 October 2017 September 2017 August 2017 July 2017 June 2017 May 2017 April 2017 March 2017 January 2017 December 2016 November 2016 October 2016 September 2016 August 2016 July 2016 June 2016 May 2016 April 2016 March 2016 February 2016 January 2016 December 2015 November 2015 October 2015 September 2015 August 20...
# Searching the web for: recent advancements in artificial intelligence diagnostic imaging healthcare 2023
# <Response [200]>
# Extracted content: 403 403 Forbidden
# Searching the web for: artificial intelligence healthcare diagnostic imaging 2023 applications advancements
# <Response [200]>
# Extracted content:
# Extracted content: News | Healthcare IT News Skip to main content News CommonSpirit partners up with U of U for clinical collaboration By Andrea Fox 04:29 pm November 22, 2024 Patients from five of the health system's hospitals will now have access to University of Utah Health providers and resources through the new community-based partnership. AI & ML Intelligence HIMSSCast: Care provider or tool? When and why patients like AI By Andrea Fox 10:27 am November 22, 2024 Mark Polyak, president of analytics at IPSOS, and Dr. Lukasz Kowalczyk, a gastroenterolgy physician, offer a data-driven discussion about how patients feel about artificial intelligence, and how they want it used in their care. EHR tips on migrating an all-digital hospital to Epic By Bill Siwicki 10:23 am November 22, 2024 Oklahoma Heart Hospital CIO David Miles and his team made it through in one piece. He offers tips for those facing an electronic health record switch, discusses staff resistance – and talks about what it takes to successfully work with a consulting firm. House passes veterans healthcare package without RESET Act By Andrea Fox 11:22 am November 21, 2024 The revised bill now leaves out provisions that would have increased Congressional oversight over the VA's EHR modernization partnership with Oracle, which is set to restart in 2025. Deep dive: A tour of all-digital Oklahoma Heart Hospital, where automation is the norm By Bill Siwicki 10:57 am November 21, 2024 Improving the care experience through technology is at the core of the cardiovascular center's values, says its CIO – who describes how the two-hospital system uses patient feedback to focus on optimal care delivery, and has the accolades to prove it. Sponsored Streamlining healthcare operations with multicloud-by-design By 09:55 am November 21, 2024 When healthcare organizations require multiple public cloud providers, leveraging them in a strategic fashion improves overall efficiency, performance and security. All private hospitals in Singapore ...
# Extracted content: 404 Page Not Found | American Medical Association Skip to main content 404 Page Not Found Looks like something went wrong, and we couldn’t find that page. Please visit our home page for other AMA news and information, and learn more about our featured products and initiatives. For immediate assistance, please call 800-621-8335. We are focused on addressing the issues important to you, so you can focus on what matters most—patients. Why We Fight Join the nation’s largest physician organization and enjoy benefits to enhance your practice and personal and professional life. Member Benefits Stay up to date with the latest information on hot topics in health care and medicine with the AMA. Press Center Find resources from the AMA to help accurately bill outpatient and office procedures and services with Current Procedural Terminology (CPT) and Healthcare Common Procedure Coding System (HCPCS) codes. CPT® Discover events advocating for the interests of American physicians, improving public health, and supporting sound medical policy at the federal and local levels. Events Participate in groups that offer members the opportunity to shape AMA policy, increase knowledge and skills, and interact with peers with similar interests or backgrounds. Member Groups (Sections) Also of Interest: Health Information Technology Substance Use Disorders Health Care AI
# Searching the web for: AI applications in diagnostic imaging healthcare 2023
# <Response [200]>
# Extracted content: ScienceDirect ! There was a problem providing the content you requested Please contact us via our
# support center for more information and provide the details below. Reference Number: 8e71c242c9706575 IP Address: 4.180.183.243 User Agent: Timestamp: ::CLOUDFLARE_ERROR_1000S_BOX::
# Searching the web for: latest advancements artificial intelligence healthcare diagnostic imaging 2023
# <Response [200]>
# Extracted content: 403 Forbidden Forbidden You don't have permission to access this resource.
# Extracted content: Page Not Found | The BMJ Skip to main content Page Not Found Unfortunately the page "content/379/bmj.n1784" you are looking for cannot be found. This may be the result of a broken link on the page you have come from, or you may have mistyped the web address. You could: Try again. Go back to the previous page. Go to The BMJ homepage . Contact BMJ Customer Services for assistance.
# Searching the web for: current trends artificial intelligence diagnostic imaging 2023
# <Response [200]>
# Extracted content: Just a moment... Enable JavaScript and cookies to continue
# Searching the web for: artificial intelligence diagnostic imaging review article 2023
# <Response [200]>
#
# Research Results:
#
#
# Thought Process:
# - Original request:
#     Find information about artificial intelligence in healthcare.
#     Focus on recent applications in diagnostic imaging.
#     Create a summary of the findings.
#
#
# You are in the process of helping the user fulfill this request using the following plan:
# Here’s a step-by-step plan to achieve the goal of finding information about artificial intelligence in healthcare, specifically focusing on recent applications in diagnostic imaging, and creating a summary of the findings:
#
# 1. **Search the Web**: Use the `web-SearchWeb` function to search for recent applications of artificial intelligence in diagnostic imaging within healthcare.
#
# 2. **Extract Content**: Use the `web-ExtractContent` function to extract the main content from the relevant URLs obtained from the web search.
#
# 3. **Analyze Content**: Use the `ResearchPlugin-AnalyzeContent` function to analyze the extracted content and identify key points related to the applications of AI in diagnostic imaging.
#
# 4. **Create Summary**: Use the `ResearchPlugin-CreateSummary` function to create a summary from the analyzed content.
#
# 5. **Send Final Answer**: Use the `UserInteraction-SendFinalAnswer` function to communicate the summary back to the user.
#
# Now, I will proceed with step 1 by searching the web for information on artificial intelligence in healthcare, focusing on diagnostic imaging.
#
# Executing step 1...
#
# **Searching the web for recent applications of artificial intelligence in diagnostic imaging.**
#
# Let's perform the search.
#
# ```json
# {"query":"recent applications of artificial intelligence in
#
# The user will ask you for help with each step.
# - Perform the next step of the plan if there is more work to do. When you have reached a final answer, use the UserInteraction-SendFinalAnswer function to communicate this back to the user.
# -
# -
# - Perform the next step of the plan if there is more work to do. When you have reached a final answer, use the UserInteraction-SendFinalAnswer function to communicate this back to the user.
# -
# -
# - Perform the next step of the plan if there is more work to do. When you have reached a final answer, use the UserInteraction-SendFinalAnswer function to communicate this back to the user.
# -
# -
# - Perform the next step of the plan if there is more work to do. When you have reached a final answer, use the UserInteraction-SendFinalAnswer function to communicate this back to the user.
# -
# -
# - Perform the next step of the plan if there is more work to do. When you have reached a final answer, use the UserInteraction-SendFinalAnswer function to communicate this back to the user.
# -
# -
# - Perform the next step of the plan if there is more work to do. When you have reached a final answer, use the UserInteraction-SendFinalAnswer function to communicate this back to the user.
# -
# -
# - Perform the next step of the plan if there is more work to do. When you have reached a final answer, use the UserInteraction-SendFinalAnswer function to communicate this back to the user.
# -
# -
# - Perform the next step of the plan if there is more work to do. When you have reached a final answer, use the UserInteraction-SendFinalAnswer function to communicate this back to the user.
# -
# -
# - Perform the next step of the plan if there is more work to do. When you have reached a final answer, use the UserInteraction-SendFinalAnswer function to communicate this back to the user.
# -
# -
# - Perform the next step of the plan if there is more work to do. When you have reached a final answer, use the UserInteraction-SendFinalAnswer function to communicate this back to the user.
# -
# -
# - Perform the next step of the plan if there is more work to do. When you have reached a final answer, use the UserInteraction-SendFinalAnswer function to communicate this back to the user.
# -
# -
# - Perform the next step of the plan if there is more work to do. When you have reached a final answer, use the UserInteraction-SendFinalAnswer function to communicate this back to the user.
# -
# -
# -
# - Perform the next step of the plan if there is more work to do. When you have reached a final answer, use the UserInteraction-SendFinalAnswer function to communicate this back to the user.
# -
# -
# - Perform the next step of the plan if there is more work to do. When you have reached a final answer, use the UserInteraction-SendFinalAnswer function to communicate this back to the user.
# -
# -
# - Perform the next step of the plan if there is more work to do. When you have reached a final answer, use the UserInteraction-SendFinalAnswer function to communicate this back to the user.
# -
# -
#
# ================================================================================

# %% [markdown]
# ## 5. Best Practices
#
#
# Always provide clear, specific goals
# Include error handling
# Monitor plan execution steps
# Validate results at each stage
